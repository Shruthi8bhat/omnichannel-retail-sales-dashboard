# %% [markdown]
# # Omnichannel Retail Sales & Inventory Analytics
# Data Cleaning and Initial Exploration

# %%
import pandas as pd

train = pd.read_csv("clean_train.csv")
test = pd.read_csv("clean_test.csv")

train.head()

# %% [markdown]
# ## Dataset Overview

# %%
train.shape
train.columns
train.info()

# %% [markdown]
# ## Basic Analysis Examples

# %%
# Total revenue
train['sales_revenue'].sum()

# %%
# Sales by region
train.groupby('region')['sales_revenue'].sum().sort_values(ascending=False)

# %%
# Sales by channel
train.groupby('channel')['sales_revenue'].sum()
